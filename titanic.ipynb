# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv("./data/train.csv")

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
matrix = np.array([train_data['Pclass'].tolist(),
train_data['Fare'].tolist()]).transpose()

# %%
train_data['Age']

# %%
passenger_class = train_data['Pclass'].tolist()

# %%
passenger_fare = train_data['Fare'].tolist()
print(min(passenger_fare))
max(passenger_fare)
# Out:
# 0.0
# 512.3292

# %%
tickets = train_data['Ticket'].tolist()

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(passenger_class, passenger_fare, 'ro')
plt.axis([0, 3.5, 0, 550])
plt.show()

# %%
plt.plot(tickets, passenger_fare, 'ro')
plt.show()

# %%
len(train_data[train_data.Age.notnull()]['Age'].tolist())
# Out:
# 714

# %%
len(train_data['Age'].tolist())
# Out:
# 891

# %%
df = train_data[train_data.Age.isnull()]

# %%
age_data = train_data[train_data.Age.notnull()]

# %%
merged = age_data[['Age', 'SibSp', 'Parch']]

# %%
plt.plot(merged['Age'].tolist(), merged['SibSp'].tolist(), 'ro')
plt.show()

# %%
plt.plot(merged['Age'].tolist(), merged['Parch'].tolist(), 'ro')
plt.show()
